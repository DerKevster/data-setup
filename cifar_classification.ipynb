# %% [markdown]
# <a href="https://colab.research.google.com/github/DerKevster/data-setup/blob/master/cifar_classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CIFAR10 Classification Problem

# %% [markdown]
# 🎯 **Exercise objectives**
#
# * 1️⃣ Implement a CNN to solve a **`10-class classification problem`**
#
# * 2️⃣ Enhance the CNN's performance with **`Data Augmentation Techniques`**
#
# * 3️⃣ Experiment with **`GPUs to Accelerate Image Processing using Google Colab`**
#
# <hr>
#
#
# 👏 You should now have a better feeling of:
# * how CNNs works,
# * and especially how convolutions scan images to detect specific spatial features.
#
# 🚀 It's time to play with images that are a bit more complex than the handwritten digits or the triangles/circles.
#
# 🎨 From [Wikipedia](https://en.wikipedia.org/wiki/CIFAR-10) (*click on the link for further information*):
#
# > The **`CIFAR-10`** dataset (Canadian Institute For Advanced Research) is a collection of images that are commonly used to train machine learning and computer vision algorithms. It is one of the most widely used datasets for machine learning research. The CIFAR-10 dataset contains 60,000 32x32 color images in 10 different classes. The 10 different classes represent airplanes, cars, birds, cats, deer, dogs, frogs, horses, ships, and trucks. There are 6,000 images of each class.
#
# <img src="https://people.minesparis.psl.eu/fabien.moutarde/ES_MachineLearning/mini-projets/cifar10_notebook_fichiers/cifar_10.png">
#
# ⭐️ This dataset is iconic in the research community as many enhancements for image recognition have been achieved on this dataset. After achieving great performance on this dataset, researchers moved to the more advanced CIFAR-100.
#
# From the [University of Toronto](https://www.cs.toronto.edu/~kriz/cifar.html):
#
# > This dataset is just like the CIFAR-10, except it has 100 classes containing 600 images each. There are 500 training images and 100 testing images per class. The 100 classes in the CIFAR-100 are grouped into 20 superclasses. Each image comes with a "fine" label (the class to which it belongs) and a "coarse" label (the superclass to which it belongs).
#
#
# 🔥 In this notebook, let's ***implement a CNN to distinguish the 10 categories from the CIFAR-10 dataset***.
#
# ❗️ Again, remember that until 10 years ago, this problem was very challenging for the entire research community. As you have been sharpening your CNN skills, it is time to shine!

# %% [markdown]
# ## 🛠 Google Colab Setup

# %% [markdown]
# If you are planning to use Google Colab (which is strongly recommended for this challenge), there is a few things you need to take care of first so that you can run everything properly.
#
# * If you want to get started, follow these four steps.
# * You can also read Davy's tutorial on Kitt 👉 [Introduction to Google Colab](https://kitt.lewagon.com/knowledge/tutorials/data_google_colab)

# %% [markdown]
# ### Step 1: Upload the Challenge Folder to Google Drive and Open it in Colab

# %% [markdown]
# If you want Google Colab to be able to run this notebook, you need to ***upload all the necessary files to your Google Drive***.
#
# To do this, simply:
# 1. Access your [Google Drive](https://drive.google.com/)
# 2. Go into the `Colab Notebooks folder`
# 3. Drag-and-drop this `challenge's folder` into it
# 4. Right-click the notebook file and select `Open with` $\rightarrow$ `Google Colaboratory`

# %% [markdown]
# ### Step 2: Mount Google Drive

# %% [markdown]
# The previous was necessary but not enough. For security purposes, Google Colab and Google Drive are NOT connected even if they belong to the same Google Account
#
# We need to ***mount the main directory of the Google Drive associated with the account being used for Colab***.
#
# *Note: if you're getting errors when authenticating, try to do it in Google Chrome, as other browsers tend to experience issues.*

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ⬅️ On the left sidebar, there is a 🗂 folder icon.
# * If you click on it, you should now see a folder called `drive/MyDrive`. This is your Google Drive and all its content!

# %% [markdown]
# ### Step 3: Navigate to the Challenge Directory

# %% [markdown]
# One more thing: we need to  this notebook in the context of the challenge's folder.
#
# Simply run the cell down below.

# %%
import os

# os.chdir allows you to change directories, like cd in the Terminal
os.chdir('/content/drive/MyDrive/Colab Notebooks/data-cifar-classification')

# %% [markdown]
# ### Step 4: Toggle GPU Acceleration

# %% [markdown]
# As a last step, we should take advantage of Google Colab by enabling GPU acceleration for our notebook.
#
# You can do it by navigating through the menu bar:
#
# `Runtime` $\rightarrow$ `Change runtime type` $\rightarrow$ `Hardware accelerator`
#
# and select "GPU" from the dropdown menu.

# %% [markdown]
# 🚀 You are now ready to start, proceed with the challenge! 🚀

# %% [markdown]
# ## (1) Loading the CIFAR10 Dataset

# %% [markdown]
# ❓ **Question: Loading the CIFAR10 Dataset** ❓
#
#
# * 🎁 We took care of the `data loading and preprocessing` for you.
# * ▶️ Just run the following cell and make sure you understand the code.

# %%
from tensorflow.keras.datasets import cifar10
import numpy as np

(images_train, labels_train), (images_test, labels_test) = cifar10.load_data()

labels = ['airplane', 
          'automobile',
          'bird',
          'cat',
          'deer',
          'dog',
          'frog',
          'horse',
          'ship',
          'truck']

print(images_train.shape, images_test.shape)
unique, counts = np.unique(labels_train, return_counts=True)
dict(zip(unique, counts))
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 14s 0us/step
# (50000, 32, 32, 3) (10000, 32, 32, 3)
# {0: 5000,
#  1: 5000,
#  2: 5000,
#  3: 5000,
#  4: 5000,
#  5: 5000,
#  6: 5000,
#  7: 5000,
#  8: 5000,
#  9: 5000}

# %% [markdown]
# ### (1.2) Image preprocesing

# %% [markdown]
# ### (1.1) Working on a smaller dataset?

# %% [markdown]
# ❓ **Question about the training size** ❓
#
# * It will probably take a very long time to train a model on $50 000$ images m...
# * 👨🏻‍🏫 **Always start with a subsample to iterate quickly** before scaling up! 🆙
# * Run the next cell where we are reducing the dataset size by `reduction_factor = 10`. Don't try to increase it unless we ask you to do so...

# %%
# Considering only 1/10th of the 50_000 images
reduction_factor = 10

# Choosing the random indices of small train set and small test set
idx_train =  np.random.choice(len(images_train), round(len(images_train)/reduction_factor), replace=False)
idx_test =  np.random.choice(len(images_test), round(len(images_test)/reduction_factor), replace=False)

# Collecting the two subsamples images_train_small and images_test_small from images_train and images_test
images_train_small = images_train[idx_train]
images_test_small = images_test[idx_test]
# and their corresponding labels
labels_train_small = labels_train[idx_train]
labels_test_small = labels_test[idx_test]

print("------------------ Before -----------------")
print(images_train.shape, images_test.shape)

print("")

print("--- After applying the reduction factor ---")
print(images_train_small.shape, images_test_small.shape)

print("")
print("-"*43)

unique, counts = np.unique(labels_train_small, return_counts=True)
dict(zip(unique, counts))
# Out:
# ------------------ Before -----------------
# (50000, 32, 32, 3) (10000, 32, 32, 3)
#
# --- After applying the reduction factor ---
# (5000, 32, 32, 3) (1000, 32, 32, 3)
#
# -------------------------------------------
# {0: 505,
#  1: 495,
#  2: 488,
#  3: 503,
#  4: 482,
#  5: 514,
#  6: 502,
#  7: 501,
#  8: 484,
#  9: 526}

# %% [markdown]
# 👇 You are working with images.. so it would be a good idea to have a look at some of them :)

# %%
# Let's plot few images to see what they look like
import matplotlib.pyplot as plt

plt.figure(figsize=(15,5))
for i in range(6):
    plt.subplot(1,6, i+1)
    img = images_train[i]
    label = labels_train[i][0]
    plt.imshow(img)
    plt.title(labels[label])

# %% [markdown]
# 👉 As usual, let's:
# - normalize the pixels' intensities between 0 and 1
# - turn the `labels_train` and `labels_test` into "one-hot-encoded" targets that we will call respectively `y_train` and `y_test`

# %%
### Normalizing pixels' intensities
X_train = images_train / 255.
X_train_small = images_train_small / 255.
X_test = images_test / 255.
X_test_small = images_test_small / 255.

### Encoding the labels
from tensorflow.keras.utils import to_categorical
y_train = to_categorical(labels_train, 10)
y_train_small = to_categorical(labels_train_small, 10)
y_test = to_categorical(labels_test, 10)
y_test_small = to_categorical(labels_test_small, 10)

# %% [markdown]
# ## (2) Iterate on your CNN architecture using your small training set

# %% [markdown]
# ❓ **Question** ❓ Time to shine ⭐️⭐️⭐️ !
#
# 1. Define the CNN architecture of your choice in an `initialize_model()` function:
# 2. Compile your model in a `compile_model()` method:
# 3. Fit your CNN only on the `small training set` and save the training information in an `history` variable
# ---
# * Feeling lost?
# * Do you want to improve your performance ?
#
# <details>
#     <summary>🆘 PRO TIPS 🆘</summary>
#
#
# - Do not forget to add the **`input shape`** of your images to the first layer: it has 3 colors
# - **`Start simple, add complexify later `** after several attempts to get better results
# - The task is complex: **`Try at least 3 or 4 convolutions`**, you want your **images to go through different magnifying glasses / kernels from different convolutional layers!**
# - The Kernel Size does not need to be large for such a small picture resolution!
# - Add some **`MaxPooling2D`** (but not too much, otherwise the activation "image" will become too small)
# - Keep `padding = "same"` and `stride = (1,1)` to start with.
# - Once your model overfits, try to add some **`Dropout Layers` to regularize the network**. A good tip is to **increase the Dropout Rate/Strength as you move closer to the prediction layer** to prevent your CNN from overfitting
# - Images are so small in CIFAR10, you can afford to use a larger batch size (32 or 64) to benefit even more from **GPU parallelization**!
# </details>
#
# ---

# %%
X_test.shape
# Out:
# (10000, 32, 32, 3)

# %%
from tensorflow.keras import layers
from tensorflow.keras import models
from tensorflow.keras import optimizers

def initialize_model():
    '''instanciate and return the CNN architecture of your choice with less than 150,000 params'''
    
    model = models.Sequential()

    ### First Convolution & MaxPooling   
    model.add(layers.Conv2D(16, kernel_size=(4, 4), activation='relu', input_shape=(32, 32, 3), padding='same'))
    model.add(layers.MaxPool2D(pool_size=(2,2)))
    
    ### Second Convolution & MaxPooling
    model.add(layers.Conv2D(64, kernel_size=(3, 3), activation='relu'))
    model.add(layers.MaxPool2D(pool_size=(2,2)))
        
    ### Dropout
    model.add(layers.Dropout(0.1))
    
    ### Third Convolution & MaxPooling
    model.add(layers.Conv2D(128, kernel_size=(3, 3), activation='relu'))
    
    ### Dropout
    model.add(layers.Dropout(0.3))

    ### Forth Convolution & MaxPooling
    model.add(layers.Conv2D(128, kernel_size=(2, 2), activation='relu'))

    ### Dropout
    model.add(layers.Dropout(0.5))
    
    ### Flattening
    model.add(layers.Flatten())
    
    ### One Fully Connected layer - "Fully Connected" is equivalent to saying "Dense"
    model.add(layers.Dense(10, activation='relu'))
    
    ### Last layer - Classification Layer with 10 outputs corresponding to 10 digits
    model.add(layers.Dense(10, activation='softmax'))
    
    return model

# %%
def compile_model(model):
    '''return a compiled model suited for the CIFAR-10 task'''

    ### Model compilation
    model.compile(loss='categorical_crossentropy', 
              optimizer='adam',
              metrics=['accuracy'])

# %%
model = initialize_model()
compile_model(model)
model.summary()
# Out:
# Model: "sequential_17"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_61 (Conv2D)          (None, 32, 32, 16)        784
#
#  max_pooling2d_49 (MaxPoolin  (None, 16, 16, 16)       0
#  g2D)
#
#  conv2d_62 (Conv2D)          (None, 14, 14, 64)        9280
#
#  max_pooling2d_50 (MaxPoolin  (None, 7, 7, 64)         0
#  g2D)
#
#  dropout_41 (Dropout)        (None, 7, 7, 64)          0
#
#  conv2d_63 (Conv2D)          (None, 5, 5, 128)         73856
#
#  dropout_42 (Dropout)        (None, 5, 5, 128)         0
#
#  conv2d_64 (Conv2D)          (None, 4, 4, 128)         65664
#
#  dropout_43 (Dropout)        (None, 4, 4, 128)         0
#
#  flatten_11 (Flatten)        (None, 2048)              0
#
#  dense_22 (Dense)            (None, 10)                20490
#
#  dense_23 (Dense)            (None, 10)                110
#
# =================================================================
# Total params: 170,184
# Trainable params: 170,184
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.callbacks import EarlyStopping
es = EarlyStopping(patience=30, restore_best_weights=True)

history = model.fit(X_train_small, y_train_small, epochs=1000, batch_size=32, validation_split=0.3, callbacks=[es])
# Out:
# Epoch 1/1000
# 110/110 [==============================] - 66s 10ms/step - loss: 2.2811 - accuracy: 0.1343 - val_loss: 2.2640 - val_accuracy: 0.1193
# Epoch 2/1000
# 110/110 [==============================] - 1s 7ms/step - loss: 2.1095 - accuracy: 0.2209 - val_loss: 1.9780 - val_accuracy: 0.2593
# Epoch 3/1000
# 110/110 [==============================] - 1s 7ms/step - loss: 1.9343 - accuracy: 0.2874 - val_loss: 1.8872 - val_accuracy: 0.2967
# Epoch 4/1000
# 110/110 [==============================] - 1s 7ms/step - loss: 1.8293 - accuracy: 0.3114 - val_loss: 1.7985 - val_accuracy: 0.3167
# Epoch 5/1000
# 110/110 [==============================] - 1s 7ms/step - loss: 1.7337 - accuracy: 0.3526 - val_loss: 1.7682 - val_accuracy: 0.3553
# Epoch 6/1000
# 110/110 [==============================] - 1s 7ms/step - loss: 1.6800 - accuracy: 0.3726 - val_loss: 1.7194 - val_accuracy: 0.3693
# Epoch 7/1000
# 110/110 [==============================] - 1s 7ms/step - loss: 1.6176 - accuracy: 0.3929 - val_loss: 1.7231 - val_accuracy: 0.3653
# Epoch 8/1000
# 110/110 [==============================] - 1s 7ms/step - loss: 1.5680 - accuracy: 0.4086 - val_loss: 1.6424 - val_accuracy: 0.4027
# Epoch 9/1000
# 110/110 [==============================] - 1s 7ms/step - loss: 1.5392 - accuracy: 0.4269 - val_loss: 1.6273 - val_accuracy: 0.3973
# Epoch 10/1000
# 110/110 [==============================] - 1s 7ms/step - loss: 1.4704 - accuracy: 0.4437 - val_loss: 1.6092 - val_accuracy: 0.4033
# Epoch 11/1000
# 110/110 [==============================] - 1s 8ms/step - loss: 1.4269 - accuracy: 0.4560 - val_loss: 1.5286 - val_accuracy: 0.4393
# Epoch 12/1000
# 110/110 [==============================] - 1s 11ms/step - loss: 1.3855 - accuracy: 0.4823 - val_loss: 1.5479 - val_accuracy: 0.4293
# Epoch 13/1000
# 110/110 [==============================] - 1s 9ms/step - loss: 1.3508 - accuracy: 0.4954 - val_loss: 1.4947 - val_accuracy: 0.4633
# Epoch 14/1000
# 110/110 [==============================] - 1s 7ms/step - loss: 1.2674 - accuracy: 0.5194 - val_loss: 1.5122 - val_accuracy: 0.4653
# Epoch 15/1000
# 110/110 [==============================] - 1s 7ms/step - loss: 1.2511 - accuracy: 0.5334 - val_loss: 1.4813 - val_accuracy: 0.4540
# Epoch 16/1000
# 110/110 [==============================] - 1s 7ms/step - loss: 1.2114 - accuracy: 0.5466 - val_loss: 1.4753 - val_accuracy: 0.4593
# Epoch 17/1000
# 110/110 [==============================] - 1s 7ms/step - loss: 1.1559 - accuracy: 0.5646 - val_loss: 1.4607 - val_accuracy: 0.4753
# Epoch 18/1000
# 110/110 [==============================] - 1s 7ms/step - loss: 1.1003 - accuracy: 0.5829 - val_loss: 1.4139 - val_accuracy: 0.4927
# Epoch 19/1000
# 110/110 [==============================] - 1s 7ms/step - loss: 1.0407 - accuracy: 0.6137 - val_loss: 1.4804 - val_accuracy: 0.4807
# Epoch 20/1000
# 110/110 [==============================] - 1s 7ms/step - loss: 1.0168 - accuracy: 0.6129 - val_loss: 1.4853 - val_accuracy: 0.4760
# Epoch 21/1000
# 110/110 [==============================] - 1s 7ms/step - loss: 1.0079 - accuracy: 0.6200 - val_loss: 1.4069 - val_accuracy: 0.4913
# Epoch 22/1000
# 110/110 [==============================] - 1s 7ms/step - loss: 0.9503 - accuracy: 0.6406 - val_loss: 1.5547 - val_accuracy: 0.4933
# Epoch 23/1000
# 110/110 [==============================] - 1s 7ms/step - loss: 0.9125 - accuracy: 0.6597 - val_loss: 1.4502 - val_accuracy: 0.5087
# Epoch 24/1000
# 110/110 [==============================] - 1s 7ms/step - loss: 0.8615 - accuracy: 0.6689 - val_loss: 1.3919 - val_accuracy: 0.5173
# Epoch 25/1000
# 110/110 [==============================] - 1s 7ms/step - loss: 0.8385 - accuracy: 0.6777 - val_loss: 1.4280 - val_accuracy: 0.5300
# Epoch 26/1000
# 110/110 [==============================] - 1s 9ms/step - loss: 0.8206 - accuracy: 0.6769 - val_loss: 1.4475 - val_accuracy: 0.5153
# Epoch 27/1000
# 110/110 [==============================] - 1s 9ms/step - loss: 0.7966 - accuracy: 0.6983 - val_loss: 1.4078 - val_accuracy: 0.5407
# Epoch 28/1000
# 110/110 [==============================] - 1s 8ms/step - loss: 0.7366 - accuracy: 0.7303 - val_loss: 1.5547 - val_accuracy: 0.5207
# Epoch 29/1000
# 110/110 [==============================] - 1s 7ms/step - loss: 0.7147 - accuracy: 0.7229 - val_loss: 1.5109 - val_accuracy: 0.5127
# Epoch 30/1000
# 110/110 [==============================] - 1s 7ms/step - loss: 0.6667 - accuracy: 0.7411 - val_loss: 1.5690 - val_accuracy: 0.5073
# Epoch 31/1000
# 110/110 [==============================] - 1s 7ms/step - loss: 0.6375 - accuracy: 0.7546 - val_loss: 1.5630 - val_accuracy: 0.5220
# Epoch 32/1000
# 110/110 [==============================] - 1s 7ms/step - loss: 0.6295 - accuracy: 0.7554 - val_loss: 1.5846 - val_accuracy: 0.5240
# Epoch 33/1000
# 110/110 [==============================] - 1s 7ms/step - loss: 0.6031 - accuracy: 0.7686 - val_loss: 1.6392 - val_accuracy: 0.5200
# Epoch 34/1000
# 110/110 [==============================] - 1s 7ms/step - loss: 0.5878 - accuracy: 0.7711 - val_loss: 1.6495 - val_accuracy: 0.5247
# Epoch 35/1000
# 110/110 [==============================] - 1s 7ms/step - loss: 0.5365 - accuracy: 0.7937 - val_loss: 1.6916 - val_accuracy: 0.5353
# Epoch 36/1000
# 110/110 [==============================] - 1s 7ms/step - loss: 0.5583 - accuracy: 0.7837 - val_loss: 1.6846 - val_accuracy: 0.5140
# Epoch 37/1000
# 110/110 [==============================] - 1s 7ms/step - loss: 0.5119 - accuracy: 0.8157 - val_loss: 1.6686 - val_accuracy: 0.5407
# Epoch 38/1000
# 110/110 [==============================] - 1s 7ms/step - loss: 0.4970 - accuracy: 0.8091 - val_loss: 1.6820 - val_accuracy: 0.5333
# Epoch 39/1000
# 110/110 [==============================] - 1s 7ms/step - loss: 0.4874 - accuracy: 0.8194 - val_loss: 1.6732 - val_accuracy: 0.5260
# Epoch 40/1000
# 110/110 [==============================] - 1s 7ms/step - loss: 0.4552 - accuracy: 0.8269 - val_loss: 1.8005 - val_accuracy: 0.5240
# Epoch 41/1000
# 110/110 [==============================] - 1s 9ms/step - loss: 0.4633 - accuracy: 0.8220 - val_loss: 1.8093 - val_accuracy: 0.5307
# Epoch 42/1000
# 110/110 [==============================] - 1s 9ms/step - loss: 0.4335 - accuracy: 0.8354 - val_loss: 1.8686 - val_accuracy: 0.5207
# Epoch 43/1000
# 110/110 [==============================] - 1s 8ms/step - loss: 0.4233 - accuracy: 0.8400 - val_loss: 1.7978 - val_accuracy: 0.5400
# Epoch 44/1000
# 110/110 [==============================] - 1s 7ms/step - loss: 0.3645 - accuracy: 0.8594 - val_loss: 1.8865 - val_accuracy: 0.5420
# Epoch 45/1000
# 110/110 [==============================] - 1s 7ms/step - loss: 0.4133 - accuracy: 0.8491 - val_loss: 1.8126 - val_accuracy: 0.5220
# Epoch 46/1000
# 110/110 [==============================] - 1s 7ms/step - loss: 0.3614 - accuracy: 0.8651 - val_loss: 1.9551 - val_accuracy: 0.5260
# Epoch 47/1000
# 110/110 [==============================] - 1s 7ms/step - loss: 0.4192 - accuracy: 0.8457 - val_loss: 1.8537 - val_accuracy: 0.5207
# Epoch 48/1000
# 110/110 [==============================] - 1s 7ms/step - loss: 0.3784 - accuracy: 0.8574 - val_loss: 1.8653 - val_accuracy: 0.5347
# Epoch 49/1000
# 110/110 [==============================] - 1s 7ms/step - loss: 0.3502 - accuracy: 0.8689 - val_loss: 1.9402 - val_accuracy: 0.5293
# Epoch 50/1000
# 110/110 [==============================] - 1s 7ms/step - loss: 0.3488 - accuracy: 0.8743 - val_loss: 1.8949 - val_accuracy: 0.5207
# Epoch 51/1000
# 110/110 [==============================] - 1s 7ms/step - loss: 0.3354 - accuracy: 0.8729 - val_loss: 2.0908 - val_accuracy: 0.5133
# Epoch 52/1000
# 110/110 [==============================] - 1s 7ms/step - loss: 0.3348 - accuracy: 0.8769 - val_loss: 1.9339 - val_accuracy: 0.5380
# Epoch 53/1000
# 110/110 [==============================] - 1s 7ms/step - loss: 0.3129 - accuracy: 0.8837 - val_loss: 2.0829 - val_accuracy: 0.5393
# Epoch 54/1000
# 110/110 [==============================] - 1s 7ms/step - loss: 0.3134 - accuracy: 0.8883 - val_loss: 1.9592 - val_accuracy: 0.5373

# %% [markdown]
# ❓ **Question: History of your training** ❓
#
# Run the following function on the previous history
# _(keep the default arguments, these are intended for future plots in the notebook)_

# %%
def plot_history(history, title='', axs=None, exp_name=""):
    if axs is not None:
        ax1, ax2 = axs
    else:
        f, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))
    
    if len(exp_name) > 0 and exp_name[0] != '_':
        exp_name = '_' + exp_name
    ax1.plot(history.history['loss'], label = 'train' + exp_name)
    ax1.plot(history.history['val_loss'], label = 'val' + exp_name)
    ax1.set_ylim(0., 2.2)
    ax1.set_title('loss')
    ax1.legend()

    ax2.plot(history.history['accuracy'], label='train accuracy'  + exp_name)
    ax2.plot(history.history['val_accuracy'], label='val accuracy'  + exp_name)
    ax2.set_ylim(0.25, 1.)
    ax2.set_title('Accuracy')
    ax2.legend()
    return (ax1, ax2)

# %%
plot_history(history, title='', axs=None, exp_name="")
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f02b40d39d0>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f02b4f110a0>)

# %% [markdown]
# ❓ **Question: Evaluating your CNN** ❓
#
# * Evaluate your model on the test data and compare it with a baseline accuracy.
# * Are you satisfied with this performance?
# * Look at the `PRO TIPS` above and iterate a bit if you want to improve your performance!

# %% [markdown]
# ## (3) Increase the size of your training data

# %% [markdown]
# ❓ **Question: train your model on the full dataset** ❓
#
# - Switch to **Colab** if you haven't done it before
# - Make sure to use the **GPU acceleration** by clicking on `Runtime` $\rightarrow$ `Change runtime` $\rightarrow$ `GPU`
#
# 💡 Training neural networks on images (in each batch) can be parallelized, and this **`parallelization procedure`** can be done on **`GPU`**.
#
# ---

# %% [markdown]
# You should observe significant performance improvement
#
# Welcome to the Deep Learning paradigm, where big data makes a significant difference.
#
# But what happens if I can access only a limited amount of pictures? Think about biologists studying rare species. What can they do?
# * To improve the accuracy of a model without much work, we can **generate new data**.
# * The process is called... ⭐️ **`Data Augmentation`** ⭐️ !
# </details>

# %%
model = initialize_model()
compile_model(model)

# %%
from tensorflow.keras.callbacks import EarlyStopping
es = EarlyStopping(patience=30, restore_best_weights=True)

history = model.fit(X_train, y_train, epochs=1000, batch_size=32, validation_split=0.3, callbacks=[es])
# Out:
# Epoch 1/1000
# 1094/1094 [==============================] - 10s 7ms/step - loss: 1.8620 - accuracy: 0.2937 - val_loss: 1.5503 - val_accuracy: 0.4154
# Epoch 2/1000
# 1094/1094 [==============================] - 8s 7ms/step - loss: 1.4734 - accuracy: 0.4569 - val_loss: 1.2905 - val_accuracy: 0.5321
# Epoch 3/1000
# 1094/1094 [==============================] - 7s 7ms/step - loss: 1.2957 - accuracy: 0.5302 - val_loss: 1.2022 - val_accuracy: 0.5675
# Epoch 4/1000
# 1094/1094 [==============================] - 8s 7ms/step - loss: 1.1848 - accuracy: 0.5705 - val_loss: 1.1162 - val_accuracy: 0.6001
# Epoch 5/1000
# 1094/1094 [==============================] - 8s 7ms/step - loss: 1.1048 - accuracy: 0.6008 - val_loss: 1.0636 - val_accuracy: 0.6167
# Epoch 6/1000
# 1094/1094 [==============================] - 7s 6ms/step - loss: 1.0389 - accuracy: 0.6260 - val_loss: 1.0286 - val_accuracy: 0.6337
# Epoch 7/1000
# 1094/1094 [==============================] - 8s 7ms/step - loss: 0.9838 - accuracy: 0.6455 - val_loss: 0.9811 - val_accuracy: 0.6486
# Epoch 8/1000
# 1094/1094 [==============================] - 8s 8ms/step - loss: 0.9428 - accuracy: 0.6596 - val_loss: 0.9351 - val_accuracy: 0.6668
# Epoch 9/1000
# 1094/1094 [==============================] - 7s 6ms/step - loss: 0.9012 - accuracy: 0.6756 - val_loss: 0.9146 - val_accuracy: 0.6765
# Epoch 10/1000
# 1094/1094 [==============================] - 8s 7ms/step - loss: 0.8772 - accuracy: 0.6845 - val_loss: 0.9029 - val_accuracy: 0.6811
# Epoch 11/1000
# 1094/1094 [==============================] - 7s 6ms/step - loss: 0.8490 - accuracy: 0.6959 - val_loss: 0.8913 - val_accuracy: 0.6842
# Epoch 12/1000
# 1094/1094 [==============================] - 8s 7ms/step - loss: 0.8255 - accuracy: 0.7006 - val_loss: 0.8702 - val_accuracy: 0.6937
# Epoch 13/1000
# 1094/1094 [==============================] - 9s 8ms/step - loss: 0.8040 - accuracy: 0.7115 - val_loss: 0.8694 - val_accuracy: 0.6943
# Epoch 14/1000
# 1094/1094 [==============================] - 7s 6ms/step - loss: 0.7827 - accuracy: 0.7184 - val_loss: 0.8793 - val_accuracy: 0.6936
# Epoch 15/1000
# 1094/1094 [==============================] - 8s 7ms/step - loss: 0.7600 - accuracy: 0.7265 - val_loss: 0.8487 - val_accuracy: 0.7009
# Epoch 16/1000
# 1094/1094 [==============================] - 8s 7ms/step - loss: 0.7510 - accuracy: 0.7296 - val_loss: 0.8169 - val_accuracy: 0.7187
# Epoch 17/1000
# 1094/1094 [==============================] - 7s 7ms/step - loss: 0.7359 - accuracy: 0.7357 - val_loss: 0.8300 - val_accuracy: 0.7131
# Epoch 18/1000
# 1094/1094 [==============================] - 8s 7ms/step - loss: 0.7224 - accuracy: 0.7419 - val_loss: 0.8283 - val_accuracy: 0.7131
# Epoch 19/1000
# 1094/1094 [==============================] - 8s 7ms/step - loss: 0.6966 - accuracy: 0.7491 - val_loss: 0.8182 - val_accuracy: 0.7139
# Epoch 20/1000
# 1094/1094 [==============================] - 8s 7ms/step - loss: 0.6923 - accuracy: 0.7513 - val_loss: 0.8216 - val_accuracy: 0.7199
# Epoch 21/1000
# 1094/1094 [==============================] - 8s 7ms/step - loss: 0.6818 - accuracy: 0.7545 - val_loss: 0.7772 - val_accuracy: 0.7321
# Epoch 22/1000
# 1094/1094 [==============================] - 7s 6ms/step - loss: 0.6723 - accuracy: 0.7578 - val_loss: 0.7950 - val_accuracy: 0.7238
# Epoch 23/1000
# 1094/1094 [==============================] - 8s 7ms/step - loss: 0.6638 - accuracy: 0.7640 - val_loss: 0.7942 - val_accuracy: 0.7223
# Epoch 24/1000
# 1094/1094 [==============================] - 9s 8ms/step - loss: 0.6498 - accuracy: 0.7655 - val_loss: 0.7900 - val_accuracy: 0.7275
# Epoch 25/1000
# 1094/1094 [==============================] - 7s 7ms/step - loss: 0.6425 - accuracy: 0.7657 - val_loss: 0.8003 - val_accuracy: 0.7303
# Epoch 26/1000
# 1094/1094 [==============================] - 8s 7ms/step - loss: 0.6372 - accuracy: 0.7706 - val_loss: 0.7662 - val_accuracy: 0.7387
# Epoch 27/1000
# 1094/1094 [==============================] - 8s 7ms/step - loss: 0.6261 - accuracy: 0.7753 - val_loss: 0.8023 - val_accuracy: 0.7224
# Epoch 28/1000
# 1094/1094 [==============================] - 7s 7ms/step - loss: 0.6170 - accuracy: 0.7810 - val_loss: 0.8271 - val_accuracy: 0.7214
# Epoch 29/1000
# 1094/1094 [==============================] - 8s 7ms/step - loss: 0.6087 - accuracy: 0.7831 - val_loss: 0.7852 - val_accuracy: 0.7354
# Epoch 30/1000
# 1094/1094 [==============================] - 9s 8ms/step - loss: 0.5980 - accuracy: 0.7853 - val_loss: 0.7802 - val_accuracy: 0.7383
# Epoch 31/1000
# 1094/1094 [==============================] - 7s 6ms/step - loss: 0.5951 - accuracy: 0.7887 - val_loss: 0.7957 - val_accuracy: 0.7345
# Epoch 32/1000
# 1094/1094 [==============================] - 8s 7ms/step - loss: 0.5809 - accuracy: 0.7914 - val_loss: 0.7817 - val_accuracy: 0.7367
# Epoch 33/1000
# 1094/1094 [==============================] - 7s 7ms/step - loss: 0.5796 - accuracy: 0.7896 - val_loss: 0.7606 - val_accuracy: 0.7398
# Epoch 34/1000
# 1094/1094 [==============================] - 9s 8ms/step - loss: 0.5689 - accuracy: 0.7953 - val_loss: 0.7580 - val_accuracy: 0.7425
# Epoch 35/1000
# 1094/1094 [==============================] - 8s 7ms/step - loss: 0.5645 - accuracy: 0.7979 - val_loss: 0.7626 - val_accuracy: 0.7481
# Epoch 36/1000
# 1094/1094 [==============================] - 7s 7ms/step - loss: 0.5648 - accuracy: 0.7983 - val_loss: 0.7734 - val_accuracy: 0.7399
# Epoch 37/1000
# 1094/1094 [==============================] - 8s 7ms/step - loss: 0.5571 - accuracy: 0.8000 - val_loss: 0.7634 - val_accuracy: 0.7457
# Epoch 38/1000
# 1094/1094 [==============================] - 8s 7ms/step - loss: 0.5494 - accuracy: 0.8041 - val_loss: 0.7456 - val_accuracy: 0.7488
# Epoch 39/1000
# 1094/1094 [==============================] - 7s 7ms/step - loss: 0.5537 - accuracy: 0.7999 - val_loss: 0.8078 - val_accuracy: 0.7359
# Epoch 40/1000
# 1094/1094 [==============================] - 8s 7ms/step - loss: 0.5374 - accuracy: 0.8063 - val_loss: 0.7579 - val_accuracy: 0.7491
# Epoch 41/1000
# 1094/1094 [==============================] - 7s 7ms/step - loss: 0.5357 - accuracy: 0.8077 - val_loss: 0.7657 - val_accuracy: 0.7461
# Epoch 42/1000
# 1094/1094 [==============================] - 8s 7ms/step - loss: 0.5259 - accuracy: 0.8103 - val_loss: 0.7779 - val_accuracy: 0.7393
# Epoch 43/1000
# 1094/1094 [==============================] - 9s 8ms/step - loss: 0.5196 - accuracy: 0.8152 - val_loss: 0.7593 - val_accuracy: 0.7482
# Epoch 44/1000
# 1094/1094 [==============================] - 7s 7ms/step - loss: 0.5177 - accuracy: 0.8154 - val_loss: 0.7825 - val_accuracy: 0.7429
# Epoch 45/1000
# 1094/1094 [==============================] - 8s 7ms/step - loss: 0.5164 - accuracy: 0.8167 - val_loss: 0.7722 - val_accuracy: 0.7437
# Epoch 46/1000
# 1094/1094 [==============================] - 8s 7ms/step - loss: 0.5093 - accuracy: 0.8178 - val_loss: 0.7516 - val_accuracy: 0.7489
# Epoch 47/1000
# 1094/1094 [==============================] - 7s 7ms/step - loss: 0.5037 - accuracy: 0.8196 - val_loss: 0.7541 - val_accuracy: 0.7523
# Epoch 48/1000
# 1094/1094 [==============================] - 8s 7ms/step - loss: 0.5031 - accuracy: 0.8208 - val_loss: 0.7455 - val_accuracy: 0.7533
# Epoch 49/1000
# 1094/1094 [==============================] - 7s 7ms/step - loss: 0.4981 - accuracy: 0.8228 - val_loss: 0.7792 - val_accuracy: 0.7435
# Epoch 50/1000
# 1094/1094 [==============================] - 8s 7ms/step - loss: 0.5000 - accuracy: 0.8209 - val_loss: 0.7796 - val_accuracy: 0.7385
# Epoch 51/1000
# 1094/1094 [==============================] - 8s 7ms/step - loss: 0.4941 - accuracy: 0.8251 - val_loss: 0.7599 - val_accuracy: 0.7447
# Epoch 52/1000
# 1094/1094 [==============================] - 7s 7ms/step - loss: 0.4878 - accuracy: 0.8258 - val_loss: 0.7402 - val_accuracy: 0.7485
# Epoch 53/1000
# 1094/1094 [==============================] - 8s 7ms/step - loss: 0.4842 - accuracy: 0.8278 - val_loss: 0.7458 - val_accuracy: 0.7523
# Epoch 54/1000
# 1094/1094 [==============================] - 8s 7ms/step - loss: 0.4890 - accuracy: 0.8240 - val_loss: 0.7305 - val_accuracy: 0.7602
# Epoch 55/1000
# 1094/1094 [==============================] - 7s 7ms/step - loss: 0.4771 - accuracy: 0.8305 - val_loss: 0.7586 - val_accuracy: 0.7511
# Epoch 56/1000
# 1094/1094 [==============================] - 8s 7ms/step - loss: 0.4729 - accuracy: 0.8340 - val_loss: 0.7445 - val_accuracy: 0.7525
# Epoch 57/1000
# 1094/1094 [==============================] - 7s 7ms/step - loss: 0.4746 - accuracy: 0.8307 - val_loss: 0.7380 - val_accuracy: 0.7553
# Epoch 58/1000
# 1094/1094 [==============================] - 8s 7ms/step - loss: 0.4696 - accuracy: 0.8341 - val_loss: 0.7625 - val_accuracy: 0.7532
# Epoch 59/1000
# 1094/1094 [==============================] - 8s 7ms/step - loss: 0.4610 - accuracy: 0.8387 - val_loss: 0.7412 - val_accuracy: 0.7515
# Epoch 60/1000
# 1094/1094 [==============================] - 7s 7ms/step - loss: 0.4621 - accuracy: 0.8356 - val_loss: 0.7869 - val_accuracy: 0.7452
# Epoch 61/1000
# 1094/1094 [==============================] - 8s 7ms/step - loss: 0.4605 - accuracy: 0.8361 - val_loss: 0.7300 - val_accuracy: 0.7595
# Epoch 62/1000
# 1094/1094 [==============================] - 9s 8ms/step - loss: 0.4546 - accuracy: 0.8382 - val_loss: 0.7608 - val_accuracy: 0.7481
# Epoch 63/1000
# 1094/1094 [==============================] - 7s 7ms/step - loss: 0.4531 - accuracy: 0.8378 - val_loss: 0.7538 - val_accuracy: 0.7520
# Epoch 64/1000
# 1094/1094 [==============================] - 8s 7ms/step - loss: 0.4476 - accuracy: 0.8400 - val_loss: 0.7480 - val_accuracy: 0.7559
# Epoch 65/1000
# 1094/1094 [==============================] - 9s 8ms/step - loss: 0.4512 - accuracy: 0.8417 - val_loss: 0.7665 - val_accuracy: 0.7506
# Epoch 66/1000
# 1094/1094 [==============================] - 7s 7ms/step - loss: 0.4449 - accuracy: 0.8418 - val_loss: 0.7502 - val_accuracy: 0.7549
# Epoch 67/1000
# 1094/1094 [==============================] - 8s 7ms/step - loss: 0.4404 - accuracy: 0.8424 - val_loss: 0.7372 - val_accuracy: 0.7613
# Epoch 68/1000
# 1094/1094 [==============================] - 7s 6ms/step - loss: 0.4379 - accuracy: 0.8439 - val_loss: 0.7495 - val_accuracy: 0.7569
# Epoch 69/1000
# 1094/1094 [==============================] - 8s 7ms/step - loss: 0.4341 - accuracy: 0.8461 - val_loss: 0.7540 - val_accuracy: 0.7533
# Epoch 70/1000
# 1094/1094 [==============================] - 8s 7ms/step - loss: 0.4312 - accuracy: 0.8453 - val_loss: 0.7739 - val_accuracy: 0.7502
# Epoch 71/1000
# 1094/1094 [==============================] - 7s 7ms/step - loss: 0.4388 - accuracy: 0.8450 - val_loss: 0.7694 - val_accuracy: 0.7525
# Epoch 72/1000
# 1094/1094 [==============================] - 8s 7ms/step - loss: 0.4367 - accuracy: 0.8459 - val_loss: 0.7504 - val_accuracy: 0.7560
# Epoch 73/1000
# 1094/1094 [==============================] - 8s 7ms/step - loss: 0.4216 - accuracy: 0.8499 - val_loss: 0.7865 - val_accuracy: 0.7473
# Epoch 74/1000
# 1094/1094 [==============================] - 7s 7ms/step - loss: 0.4242 - accuracy: 0.8500 - val_loss: 0.7652 - val_accuracy: 0.7481
# Epoch 75/1000
# 1094/1094 [==============================] - 8s 7ms/step - loss: 0.4230 - accuracy: 0.8497 - val_loss: 0.7516 - val_accuracy: 0.7561
# Epoch 76/1000
# 1094/1094 [==============================] - 7s 7ms/step - loss: 0.4208 - accuracy: 0.8522 - val_loss: 0.7770 - val_accuracy: 0.7514
# Epoch 77/1000
# 1094/1094 [==============================] - 8s 7ms/step - loss: 0.4230 - accuracy: 0.8508 - val_loss: 0.7442 - val_accuracy: 0.7573
# Epoch 78/1000
# 1094/1094 [==============================] - 8s 7ms/step - loss: 0.4169 - accuracy: 0.8523 - val_loss: 0.7597 - val_accuracy: 0.7574
# Epoch 79/1000
# 1094/1094 [==============================] - 7s 7ms/step - loss: 0.4194 - accuracy: 0.8507 - val_loss: 0.7827 - val_accuracy: 0.7506
# Epoch 80/1000
# 1094/1094 [==============================] - 8s 7ms/step - loss: 0.4202 - accuracy: 0.8516 - val_loss: 0.8021 - val_accuracy: 0.7417
# Epoch 81/1000
# 1094/1094 [==============================] - 9s 8ms/step - loss: 0.4167 - accuracy: 0.8511 - val_loss: 0.7754 - val_accuracy: 0.7444
# Epoch 82/1000
# 1094/1094 [==============================] - 7s 7ms/step - loss: 0.4048 - accuracy: 0.8554 - val_loss: 0.7660 - val_accuracy: 0.7563
# Epoch 83/1000
# 1094/1094 [==============================] - 8s 7ms/step - loss: 0.4065 - accuracy: 0.8563 - val_loss: 0.7543 - val_accuracy: 0.7561
# Epoch 84/1000
# 1094/1094 [==============================] - 9s 8ms/step - loss: 0.4034 - accuracy: 0.8575 - val_loss: 0.7922 - val_accuracy: 0.7517
# Epoch 85/1000
# 1094/1094 [==============================] - 7s 7ms/step - loss: 0.4034 - accuracy: 0.8585 - val_loss: 0.7639 - val_accuracy: 0.7520
# Epoch 86/1000
# 1094/1094 [==============================] - 8s 7ms/step - loss: 0.4093 - accuracy: 0.8582 - val_loss: 0.7574 - val_accuracy: 0.7570
# Epoch 87/1000
# 1094/1094 [==============================] - 7s 7ms/step - loss: 0.4057 - accuracy: 0.8554 - val_loss: 0.7725 - val_accuracy: 0.7571
# Epoch 88/1000
# 1094/1094 [==============================] - 8s 7ms/step - loss: 0.4040 - accuracy: 0.8567 - val_loss: 0.7785 - val_accuracy: 0.7526
# Epoch 89/1000
# 1094/1094 [==============================] - 8s 7ms/step - loss: 0.4032 - accuracy: 0.8575 - val_loss: 0.8196 - val_accuracy: 0.7436
# Epoch 90/1000
# 1094/1094 [==============================] - 7s 7ms/step - loss: 0.4028 - accuracy: 0.8578 - val_loss: 0.7556 - val_accuracy: 0.7575
# Epoch 91/1000
# 1094/1094 [==============================] - 8s 7ms/step - loss: 0.3939 - accuracy: 0.8611 - val_loss: 0.8024 - val_accuracy: 0.7489

# %%
plot_history(history, title='', axs=None, exp_name="")
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f02b6459640>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f02cbfdcf40>)

# %%
evalution = model.evaluate(X_test, y_test)
# Out:
# 313/313 [==============================] - 2s 5ms/step - loss: 0.7396 - accuracy: 0.7532

# %% [markdown]
# ## (4) 🎁📚 Data augmentation

# %% [markdown]
# > ℹ️ This section contains questions and the answers are also provided. Read them carefully before moving on to the `Transfer Learning` challenge.
#
# > 👨🏻‍🏫 If you do not have time to do the `Transfer Learning` challenge, don't worry, we can talk about it during the Recap session, we are aware that this unit about Convolutional Neural Networks is quite packed... but also one of the most exciting applications of Deep Learning ❤️

# %% [markdown]
# * 👩🏻‍🏫 <b><u>Data Augmentation</u></b>
#     * This technique is widely-used and consists of applying little transformations to the input images without changing their labels: ***mirroring***, ***cropping***, ***intensity changes***, etc...
#     * The _improved performance_ simply results from the CNN training with more images (the original pictures + the "augmented" ones).
#
#
# * 👉 <b><u>Theoretically:</u></b>
#     * (1) We could generate these new images by applying some transformations on copies of the original pictures
#     * (2) Train the model on the original images + new images.
#
#
# * 🚨  <b><u>Problem:</u></b>
#     * Such a procedure requires storing all these images in memory...
#     * It can be very intensive, so much so that your computer's RAM cannot hold them all
#
#
# * 🦄 <b><u>In Practice:</u></b>
#     * When a Neural Network operates a forward/backward propagation, it requires to see only 16 pictures at a time if you chose $ batch size = 16 $ for example. It doesn't need to store all the original images or the augmented images in the RAM.
#     * For this reason, we will **augment the data on the fly (batch per batch)**. What does that mean? For every epoch and every batch, during the ***.fit()*** training procedure, we will:
#         1. Generate some `augmented data/images`
#         2. Fit the model on the images and their augmented versions
#         3. Delete the images and their augmented versions from the RAM
#         4. Repeat steps 1-2-3
#
# * 📚 <a href= "https://www.tensorflow.org/api_docs/python/tf/keras/preprocessing/image/ImageDataGenerator"><b><u>tf/keras/preprocessing/image/ImageDataGenerator</u></b></a>

# %% [markdown]
# ❓ **Question: using an ImageDataGenerator** ❓
#
# Look at the following code down below 👇
# * The general syntax may look strange but don't worry:
#     * First, focus on the arguments of the *ImageDataGenerator* which define the augmentation techniques that we are using
#     * Then, check the 📚 <a href="https://www.tensorflow.org/api_docs/python/tf/keras/preprocessing/image/ImageDataGenerator">**`ImageDataGenerator`**</a> documentation later

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(
    featurewise_center = False,
    featurewise_std_normalization = False,
    rotation_range = 10,
    width_shift_range = 0.1,
    height_shift_range = 0.1,
    horizontal_flip = True,
    zoom_range = (0.8, 1.2),
    ) 

datagen.fit(X_train)
datagen

# %%
X_augmented_iterator = datagen.flow(X_train, shuffle=False, batch_size=1)
X_augmented_iterator

# %% [markdown]
# ❗️ Always **visualize the augmented images** in order to double-check whether you can still recognize the labels yourself or not ❗️

# %%
import numpy as np

for i, (raw_image, augmented_image) in enumerate(zip(X_train, X_augmented_iterator)):
    _, (ax1, ax2) = plt.subplots(1, 2, figsize=(6, 2))
    ax1.imshow(raw_image)
    ax2.imshow(augmented_image[0])
    plt.show()
    
    if i > 10:
        break

# %% [markdown]
# ❗ **Remarks** ❗
#
# * Each image from **`X_augmented_iterator`** is an ***augmented image*** of one image located in the original `X_train` image dataset
# * This augmentation process is done once per epoch.
# * During one epoch, the model will:
#     1. *create the augmented version* of each picture from `X_train`,
#     2. for each image of `X_train`, *the model will randomly pick either the original version in `X_train` or its augmented version in `X_augmented_iterator`*
#     3. and the model will be *fitted on the combination of some original images + some augmented images*
#
# ---

# %% [markdown]
# ❓ **Question: what is the validation set when we have augmented images** ❓
#
# * Previously, we used the `validation_split` argument to let the model separate the training set into a Train/Validation split when fitting the model for each epoch.
# * It is not possible to use this kind of Train/Val Split here as **using an image in the training set and its transformation in the validation set is considered `data leakage`** !.
# * Therefore, we have to define the **`validation_data`** manually with the following commands: take time to understand the cell down below:👇

# %%
from tensorflow.keras.callbacks import EarlyStopping

# The model
model_aug = initialize_model()
compile_model(model_aug)

# The data generator
X_tr = X_train[:40000]
y_tr = y_train[:40000]
X_val = X_train[40000:]
y_val = y_train[40000:]
train_flow = datagen.flow(X_tr, y_tr, batch_size = 64)

# The early stopping criterion
es = EarlyStopping(patience = 3)

# The fit
history_aug = model_aug.fit(train_flow, 
                        epochs = 50, 
                        callbacks = [es], 
                        validation_data = (X_val, y_val))
# Out:
# Epoch 1/50
# 625/625 [==============================] - 29s 42ms/step - loss: 1.9944 - accuracy: 0.2602 - val_loss: 1.5961 - val_accuracy: 0.3949
# Epoch 2/50
# 625/625 [==============================] - 25s 39ms/step - loss: 1.5662 - accuracy: 0.4195 - val_loss: 1.3494 - val_accuracy: 0.4968
# Epoch 3/50
# 625/625 [==============================] - 27s 44ms/step - loss: 1.3892 - accuracy: 0.4885 - val_loss: 1.1800 - val_accuracy: 0.5683
# Epoch 4/50
# 625/625 [==============================] - 28s 44ms/step - loss: 1.2973 - accuracy: 0.5268 - val_loss: 1.1788 - val_accuracy: 0.5797
# Epoch 5/50
# 625/625 [==============================] - 26s 42ms/step - loss: 1.2265 - accuracy: 0.5544 - val_loss: 1.1131 - val_accuracy: 0.6031
# Epoch 6/50
# 625/625 [==============================] - 25s 41ms/step - loss: 1.1844 - accuracy: 0.5747 - val_loss: 1.0188 - val_accuracy: 0.6327
# Epoch 7/50
# 625/625 [==============================] - 26s 41ms/step - loss: 1.1472 - accuracy: 0.5857 - val_loss: 1.0233 - val_accuracy: 0.6390
# Epoch 8/50
# 625/625 [==============================] - 25s 40ms/step - loss: 1.1098 - accuracy: 0.6022 - val_loss: 0.9431 - val_accuracy: 0.6697
# Epoch 9/50
# 625/625 [==============================] - 26s 41ms/step - loss: 1.0811 - accuracy: 0.6147 - val_loss: 0.9375 - val_accuracy: 0.6692
# Epoch 10/50
# 625/625 [==============================] - 25s 39ms/step - loss: 1.0649 - accuracy: 0.6187 - val_loss: 0.8689 - val_accuracy: 0.6932
# Epoch 11/50
# 625/625 [==============================] - 25s 40ms/step - loss: 1.0398 - accuracy: 0.6270 - val_loss: 0.8550 - val_accuracy: 0.7035
# Epoch 12/50
# 625/625 [==============================] - 26s 41ms/step - loss: 1.0228 - accuracy: 0.6382 - val_loss: 0.8663 - val_accuracy: 0.6950
# Epoch 13/50
# 625/625 [==============================] - 26s 41ms/step - loss: 1.0094 - accuracy: 0.6417 - val_loss: 0.8645 - val_accuracy: 0.6994
# Epoch 14/50
# 625/625 [==============================] - 25s 39ms/step - loss: 0.9990 - accuracy: 0.6462 - val_loss: 0.8536 - val_accuracy: 0.7050
# Epoch 15/50
# 625/625 [==============================] - 25s 40ms/step - loss: 0.9788 - accuracy: 0.6518 - val_loss: 0.8120 - val_accuracy: 0.7177
# Epoch 16/50
# 625/625 [==============================] - 25s 40ms/step - loss: 0.9652 - accuracy: 0.6596 - val_loss: 0.7833 - val_accuracy: 0.7290
# Epoch 17/50
# 625/625 [==============================] - 24s 39ms/step - loss: 0.9620 - accuracy: 0.6598 - val_loss: 0.8380 - val_accuracy: 0.7092
# Epoch 18/50
# 625/625 [==============================] - 25s 39ms/step - loss: 0.9429 - accuracy: 0.6702 - val_loss: 0.7605 - val_accuracy: 0.7418
# Epoch 19/50
# 625/625 [==============================] - 25s 39ms/step - loss: 0.9344 - accuracy: 0.6686 - val_loss: 0.7899 - val_accuracy: 0.7304
# Epoch 20/50
# 625/625 [==============================] - 25s 40ms/step - loss: 0.9215 - accuracy: 0.6754 - val_loss: 0.8187 - val_accuracy: 0.7146
# Epoch 21/50
# 625/625 [==============================] - 25s 40ms/step - loss: 0.9169 - accuracy: 0.6782 - val_loss: 0.7584 - val_accuracy: 0.7371
# Epoch 22/50
# 625/625 [==============================] - 25s 39ms/step - loss: 0.9044 - accuracy: 0.6816 - val_loss: 0.7339 - val_accuracy: 0.7476
# Epoch 23/50
# 625/625 [==============================] - 25s 39ms/step - loss: 0.9001 - accuracy: 0.6852 - val_loss: 0.7984 - val_accuracy: 0.7318
# Epoch 24/50
# 625/625 [==============================] - 25s 40ms/step - loss: 0.8851 - accuracy: 0.6898 - val_loss: 0.7628 - val_accuracy: 0.7359
# Epoch 25/50
# 625/625 [==============================] - 26s 41ms/step - loss: 0.8861 - accuracy: 0.6895 - val_loss: 0.7432 - val_accuracy: 0.7491

# %% [markdown]
# 🚨 The training can be quite long here...
#
# 👉 Feel free to move on to the next exercise and come back to this notebook later to finish the last questions

# %% [markdown]
# ❓ **Question: How did the model with an augmented dataset perform?** ❓
#
# Let's plot the previous and current run histories. What do you think of the data augmentation?

# %%
plot_history(history_aug, title='', axs=None, exp_name="")
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f03401dfdc0>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f02cbf6bfa0>)

# %%
evalution_aug = model_aug.evaluate(X_test, y_test)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.7707 - accuracy: 0.7342

# %% [markdown]
# 🥡 <b><u>Some takeaways from Data Augmentation:</u></b>
#
# * Data augmentation may not improve your performance easily...
#
# * Here it even decreased the performance!
#
# * Its impact strongly depends on:
#     * the model architecture you used
#     * the learning rate,
#     * the type of augmentation chosen, etc...
#
# * Image classification is an art that requires months and years of practice to master!
#
# 🚨 **Don't spend too much time trying to finetune your model for the moment!  You have other interesting challenges to investigate!** 🚨
#
# 📚 [Here is a good example of a solution for future reference](https://machinelearningmastery.com/how-to-develop-a-cnn-from-scratch-for-cifar-10-photo-classification/).<br>
# They managed to reach an accuracy level of approx. 80%!

# %% [markdown]
# ---
#
# 🏁 **Congratulations** 🏁
#
# 1. Download this notebook from your `Google Drive` or directly from `Google Colab`
# 2. Drag-and-drop it from your `Downloads` folder to your local challenge folder
#
#
# 💾 Don't forget to push your code
#
# 3. Follow the usual procedure on your terminal, inside the challenge folder:
#       * *git add cifar_classification.ipynb*
#       * *git commit -m "I am the god of CNNs"*
#       * *git push origin master*
#
# *Hint*: To find where this Colab notebook has been saved, click on `File` $\rightarrow$ `Locate in Drive`.
#
# 🚀 It is time to move on to the **Transfer Learning** challenge!
